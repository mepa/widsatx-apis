# %% [markdown]
# ### Women in Data Science ATX Meetup - November 30, 2017
#
# # Getting Data Using APIs

# %% [markdown]
# In this notebook we introduce a few Python libraries for getting and dealing with data using web Application Programming Interfaces (APIs), then work through some examples. Here is a quick overview of the topic directed toward data scientists:
#
# https://www.analyticsvidhya.com/blog/2016/11/an-introduction-to-apis-application-programming-interfaces-5-apis-a-data-scientist-must-know/
#
# In the author's words:
# > "In simple words, an API is a (hypothetical) contract between 2 softwares saying if the user software provides input in a pre-defined format, the later with extend its functionality and provide the outcome to the user software. Think of it like this, Graphical user interface (GUI) or command line interface (CLI) allows humans to Interact with code, where as an Application programmable interface (API) allows one piece of code to interact with other code.
# ..."
#
# > "An API is a set of rules with which the interaction between various entities is defined. We are specifically talking about interaction between two software."
#
# We'll be accessing data from the following APIs:
# - [USNO Astronomical Applications Department API](http://aa.usno.navy.mil/data/docs/api.php)
# - [Google Maps APIs](https://developers.google.com/maps/web-services/)
# - [OpenWeatherMap API](https://openweathermap.org/api)
# - [Planet Data API](https://www.planet.com/docs/reference/data-api/)
# - [Twitter API](https://developer.twitter.com/en/docs)

# %% [markdown]
# ***
# ## Useful Packages
# We'll use the following packages to make requests, parse responses, and read in authorization credentials for accessing APIs that require them:
# - [requests](http://docs.python-requests.org/en/master/) "is the only Non-GMO HTTP library for Python, safe for human consumption"
# - [json](https://docs.python.org/3/library/json.html) is a common package for encoding and decoding JSON (JavaScript Object Notation)
# - [pyyaml](https://github.com/yaml/pyyaml) is a package for reading YAML (Yet Another Markup Language) formatted files

# %% [markdown]
# ### JSON Package
# Many APIs these days return data in JavaScript Object Notation (JSON) format. It looks a lot like a Python `dict`, but is a language-agnostic serialization standard. We will use the `json` package for converting JSON-formatted responses to Python data structures such as dictionaries. Double-quotes are a big deal to JSON, whereas Python is all like, "meh" (or, 'meh'?).
#
# Let's try an example of parsing JSON, taken from "Data Science from Scratch" by Joel Grus.

# %%
import json


serialized = """{ "title" : "Data Science Book",
                  "author" : "Joel Grus",
                  "publicationYear" : 2014,
                  "topics" : [ "data", "science", "data science"] }"""
print("Serialized: {}".format(type(serialized)))
print(serialized)
print("")

# parse the JSON to create a Python object
print("...parsing json...")
print("")
deserialized = json.loads(serialized)
if "data science" in deserialized["topics"]:
    print("Deserialized: {}".format(type(deserialized)))
    print(deserialized)
# Out:
# Serialized: <class 'str'>
# { "title" : "Data Science Book",
#                   "author" : "Joel Grus",
#                   "publicationYear" : 2014,
#                   "topics" : [ "data", "science", "data science"] }
#
# ...parsing json...
#
# Deserialized: <class 'dict'>
# {'title': 'Data Science Book', 'author': 'Joel Grus', 'publicationYear': 2014, 'topics': ['data', 'science', 'data science']}

# %% [markdown]
# ### Requests Package
# We will use the Python Requests library for making HTTP requests.
# - http://docs.python-requests.org/en/master/
# - http://docs.python-requests.org/en/master/user/quickstart/
#
# This package is not (yet) in the Python standard library, but it's really nice to use and well-documented. Other packages are `http.client` and `urllib`. See here: https://docs.python.org/3/library/internet.html
#
# Let's try another example from "Data Science from Scratch" for making a `GET` `HTTP` request.

# %%
import json
import requests


endpoint = "https://api.github.com/users/joelgrus/repos"

response = requests.get(endpoint)

repos = json.loads(response.text)  # "loads" means "load string"

# %% [markdown]
# Use `json.loads()` for decoding **from** JSON and `json.dumps()` for encoding **to** JSON.

# %% [markdown]
# <div class="alert alert-info">
# **Exercise:** Replace `json.loads(response.text)` with `response.json()` and verify that they return the same thing.
# </div>

# %%
## CODE HERE ##

# %%
print(json.loads(response.text)[0])
# Out:
# {'id': 11189868, 'name': 'bitstarter', 'full_name': 'joelgrus/bitstarter', 'owner': {'login': 'joelgrus', 'id': 1308313, 'avatar_url': 'https://avatars1.githubusercontent.com/u/1308313?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/joelgrus', 'html_url': 'https://github.com/joelgrus', 'followers_url': 'https://api.github.com/users/joelgrus/followers', 'following_url': 'https://api.github.com/users/joelgrus/following{/other_user}', 'gists_url': 'https://api.github.com/users/joelgrus/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/joelgrus/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/joelgrus/subscriptions', 'organizations_url': 'https://api.github.com/users/joelgrus/orgs', 'repos_url': 'https://api.github.com/users/joelgrus/repos', 'events_url': 'https://api.github.com/users/joelgrus/events{/privacy}', 'received_events_url': 'https://api.github.com/users/joelgrus/received_events', 'type': 'User', 'site_admin': False}, 'private': False, 'html_url': 'https://github.com/joelgrus/bitstarter', 'description': None, 'fork': True, 'url': 'https://api.github.com/repos/joelgrus/bitstarter', 'forks_url': 'https://api.github.com/repos/joelgrus/bitstarter/forks', 'keys_url': 'https://api.github.com/repos/joelgrus/bitstarter/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/joelgrus/bitstarter/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/joelgrus/bitstarter/teams', 'hooks_url': 'https://api.github.com/repos/joelgrus/bitstarter/hooks', 'issue_events_url': 'https://api.github.com/repos/joelgrus/bitstarter/issues/events{/number}', 'events_url': 'https://api.github.com/repos/joelgrus/bitstarter/events', 'assignees_url': 'https://api.github.com/repos/joelgrus/bitstarter/assignees{/user}', 'branches_url': 'https://api.github.com/repos/joelgrus/bitstarter/branches{/branch}', 'tags_url': 'https://api.github.com/repos/joelgrus/bitstarter/tags', 'blobs_url': 'https://api.github.com/repos/joelgrus/bitstarter/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/joelgrus/bitstarter/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/joelgrus/bitstarter/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/joelgrus/bitstarter/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/joelgrus/bitstarter/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/joelgrus/bitstarter/languages', 'stargazers_url': 'https://api.github.com/repos/joelgrus/bitstarter/stargazers', 'contributors_url': 'https://api.github.com/repos/joelgrus/bitstarter/contributors', 'subscribers_url': 'https://api.github.com/repos/joelgrus/bitstarter/subscribers', 'subscription_url': 'https://api.github.com/repos/joelgrus/bitstarter/subscription', 'commits_url': 'https://api.github.com/repos/joelgrus/bitstarter/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/joelgrus/bitstarter/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/joelgrus/bitstarter/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/joelgrus/bitstarter/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/joelgrus/bitstarter/contents/{+path}', 'compare_url': 'https://api.github.com/repos/joelgrus/bitstarter/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/joelgrus/bitstarter/merges', 'archive_url': 'https://api.github.com/repos/joelgrus/bitstarter/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/joelgrus/bitstarter/downloads', 'issues_url': 'https://api.github.com/repos/joelgrus/bitstarter/issues{/number}', 'pulls_url': 'https://api.github.com/repos/joelgrus/bitstarter/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/joelgrus/bitstarter/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/joelgrus/bitstarter/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/joelgrus/bitstarter/labels{/name}', ...

# %%
print(response.json()[0])
# Out:
# {'id': 11189868, 'name': 'bitstarter', 'full_name': 'joelgrus/bitstarter', 'owner': {'login': 'joelgrus', 'id': 1308313, 'avatar_url': 'https://avatars1.githubusercontent.com/u/1308313?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/joelgrus', 'html_url': 'https://github.com/joelgrus', 'followers_url': 'https://api.github.com/users/joelgrus/followers', 'following_url': 'https://api.github.com/users/joelgrus/following{/other_user}', 'gists_url': 'https://api.github.com/users/joelgrus/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/joelgrus/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/joelgrus/subscriptions', 'organizations_url': 'https://api.github.com/users/joelgrus/orgs', 'repos_url': 'https://api.github.com/users/joelgrus/repos', 'events_url': 'https://api.github.com/users/joelgrus/events{/privacy}', 'received_events_url': 'https://api.github.com/users/joelgrus/received_events', 'type': 'User', 'site_admin': False}, 'private': False, 'html_url': 'https://github.com/joelgrus/bitstarter', 'description': None, 'fork': True, 'url': 'https://api.github.com/repos/joelgrus/bitstarter', 'forks_url': 'https://api.github.com/repos/joelgrus/bitstarter/forks', 'keys_url': 'https://api.github.com/repos/joelgrus/bitstarter/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/joelgrus/bitstarter/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/joelgrus/bitstarter/teams', 'hooks_url': 'https://api.github.com/repos/joelgrus/bitstarter/hooks', 'issue_events_url': 'https://api.github.com/repos/joelgrus/bitstarter/issues/events{/number}', 'events_url': 'https://api.github.com/repos/joelgrus/bitstarter/events', 'assignees_url': 'https://api.github.com/repos/joelgrus/bitstarter/assignees{/user}', 'branches_url': 'https://api.github.com/repos/joelgrus/bitstarter/branches{/branch}', 'tags_url': 'https://api.github.com/repos/joelgrus/bitstarter/tags', 'blobs_url': 'https://api.github.com/repos/joelgrus/bitstarter/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/joelgrus/bitstarter/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/joelgrus/bitstarter/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/joelgrus/bitstarter/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/joelgrus/bitstarter/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/joelgrus/bitstarter/languages', 'stargazers_url': 'https://api.github.com/repos/joelgrus/bitstarter/stargazers', 'contributors_url': 'https://api.github.com/repos/joelgrus/bitstarter/contributors', 'subscribers_url': 'https://api.github.com/repos/joelgrus/bitstarter/subscribers', 'subscription_url': 'https://api.github.com/repos/joelgrus/bitstarter/subscription', 'commits_url': 'https://api.github.com/repos/joelgrus/bitstarter/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/joelgrus/bitstarter/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/joelgrus/bitstarter/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/joelgrus/bitstarter/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/joelgrus/bitstarter/contents/{+path}', 'compare_url': 'https://api.github.com/repos/joelgrus/bitstarter/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/joelgrus/bitstarter/merges', 'archive_url': 'https://api.github.com/repos/joelgrus/bitstarter/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/joelgrus/bitstarter/downloads', 'issues_url': 'https://api.github.com/repos/joelgrus/bitstarter/issues{/number}', 'pulls_url': 'https://api.github.com/repos/joelgrus/bitstarter/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/joelgrus/bitstarter/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/joelgrus/bitstarter/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/joelgrus/bitstarter/labels{/name}', ...

# %% [markdown]
# <div class="alert alert-info">
# **Exercise:** If you have a GitHub account, replace `joelgrus` with your username and explore.
# </div>

# %%
## CODE HERE ##

# %%
endpoint = "https://api.github.com/users/womenindatascienceatx/repos"
response = requests.get(endpoint)
repos = json.loads(response.text)  # "loads" means "load string"
[print(repo['name']) for repo in repos];
# Out:
# Clustering
# data-science-from-scratch-workshop
# Decision-Trees
# KNIME_2017_Workshop
# logistic-regression
# Meetup-Slides
# multiple-linear-regression-and-gradient-descent
# NaiveBayesPresentation
# Neural_Networks
# PCA_SVD
# RecommenderSystems
# SQLworkshop
# stats_and_regression
# titanic-data-munging
# titanic-EDA
# titanic-hypothesis-testing
# wids-github
# widsatx-apis
# widsatx-mapreduce
# widsatx-nlp
# widsatx-python
# wids_network_analysis

# %% [markdown]
# <div class="alert alert-info">
# **Exercise:** The `repos` object above is a list of dicts. What do you get when you make a `GET` request to the endpoints `https://api.github.com` and `https://api.github.com/users`?
# </div>

# %%
## CODE HERE ##

# %%
endpoint = "https://api.github.com"
response = requests.get(endpoint)
print(type(response.json()))

endpoint = "https://api.github.com/users"
response = requests.get(endpoint)
print(type(response.json()))
# Out:
# <class 'dict'>
# <class 'list'>

# %% [markdown]
# Let's take a closer look at what got returned (a list of dicts where each element of the list is a repo).

# %%
sorted(repos[0].keys())  # dictionary keys of the first repo in the list of repos
# Out:
# ['archive_url',
#  'archived',
#  'assignees_url',
#  'blobs_url',
#  'branches_url',
#  'clone_url',
#  'collaborators_url',
#  'comments_url',
#  'commits_url',
#  'compare_url',
#  'contents_url',
#  'contributors_url',
#  'created_at',
#  'default_branch',
#  'deployments_url',
#  'description',
#  'downloads_url',
#  'events_url',
#  'fork',
#  'forks',
#  'forks_count',
#  'forks_url',
#  'full_name',
#  'git_commits_url',
#  'git_refs_url',
#  'git_tags_url',
#  'git_url',
#  'has_downloads',
#  'has_issues',
#  'has_pages',
#  'has_projects',
#  'has_wiki',
#  'homepage',
#  'hooks_url',
#  'html_url',
#  'id',
#  'issue_comment_url',
#  'issue_events_url',
#  'issues_url',
#  'keys_url',
#  'labels_url',
#  'language',
#  'languages_url',
#  'license',
#  'merges_url',
#  'milestones_url',
#  'mirror_url',
#  'name',
#  'notifications_url',
#  'open_issues',
#  'open_issues_count',
#  'owner',
#  'private',
#  'pulls_url',
#  'pushed_at',
#  'releases_url',
#  'size',
#  'ssh_url',
#  'stargazers_count',
#  'stargazers_url',
#  'statuses_url',
#  'subscribers_url',
#  'subscription_url',
#  'svn_url',
#  'tags_url',
#  'teams_url',
#  'trees_url',
#  'updated_at',
#  'url',
#  'watchers',
#  'watchers_count']

# %% [markdown]
# Next we will use `dateutil.parser` to convert from ISO datetime format to a datetime object.

# %%
repos[0]['created_at']  # ISO datetime format
# Out:
# '2017-02-23T21:58:30Z'

# %%
from collections import Counter
from dateutil.parser import parse

parse(repos[0]['created_at'])  # datetime object
# Out:
# datetime.datetime(2017, 2, 23, 21, 58, 30, tzinfo=tzutc())

# %% [markdown]
# Now, count up the number of repos created by month and by weekday using a `Counter` object from the `collections` package.

# %%
dates = [parse(repo["created_at"]) for repo in repos]
month_counts = Counter(date.month for date in dates)
weekday_counts = Counter(date.weekday() for date in dates)

# %%
# Sort by month/weekday
print("Number of repos created by month:", sorted(month_counts.items()))
print("Number of repos created by weekday:", sorted(weekday_counts.items()))
# Out:
# Number of repos created by month: [(1, 1), (2, 1), (3, 2), (4, 2), (6, 4), (7, 2), (8, 2), (9, 4), (10, 2), (11, 1), (12, 1)]
# Number of repos created by weekday: [(0, 1), (1, 1), (2, 3), (3, 13), (4, 4)]

# %%
# Sort by counts
print(month_counts.most_common())  # What month were the most repos created?
print(weekday_counts.most_common())  # which day(s) of the week were the most repos created?
# Out:
# [(9, 4), (6, 4), (3, 2), (10, 2), (8, 2), (7, 2), (4, 2), (2, 1), (11, 1), (1, 1), (12, 1)]
# [(3, 13), (4, 4), (2, 3), (0, 1), (1, 1)]

# %% [markdown]
# ### PyYaml Library
# We will use a YAML-formatted (Yet Another Markup Language) file which we call `config.yml` for keeping configuration data all in one place, and for keeping API keys and tokens secret.
#
# You will find a file named `config.yml.template` in the same directory as this notebook. It contains entries like this:
#
# ```
# ...
# planet:
#     url: https://api.planet.com/data/v1
#     key: {PLANET_API_KEY}
# ...
# ```
#
# Please keep that file open in an editor and, as we go through the tutorial, replace the values in curly braces with your personal API keys.
#
# For example, when we get to the section on on the Planet API you would replace `{PLANET_API_KEY}` with a key looking something like this: `a3a64774d30c4749826b6be445489d3b` (not a real key, but you can generate one by signing up for an account).
#
# **IMPORTANT NOTE: DO NOT COMMIT config.yml TO GITHUB!**
# If you plan to commit any code from this tutorial to GitHub, ensure that `config.yml` is in the repository's `.gitignore` file.
#
# Next, let's make a function for loading our configuration file. We can call this whenever we make a change to `config.yml` and want to re-load the file to memory.

# %%
import yaml

def load_config():
    """load the configuration file as a python dictionary"""
    with open("config.yml", 'r') as ymlfile:
        cfg = yaml.load(ymlfile)
    return cfg

# %% [markdown]
# ***
# ## USNO Astronomical Applications Department API
# http://aa.usno.navy.mil/data/docs/api.php
#
# This API does not require any authentication credentials, so we can immediately start doing `GET` requests.
#
# In general, an API request takes the form:
# ```
# http://api.usno.navy.mil/<web_service>?<parameters>
# ```
#
# The available web services are:
# - `imagery`: synthetic images of astronomical bodies under a set of conditions
# - `moon`: dates and times of a list of primary moon phases
# - `rstt`: rise, set, and transit times for the Sun and Moon
# - `sidtime`: Greenwich mean and apparent sidereal time, local mean and apparent sidereal time, and the Equation of the Equinoxes
# - `eclipses/solar`: local circumstances for solar eclipses
# - `christian`: selected Christian observances
# - `jewish`: selected Jewish observances
# - `islamic`: selected Islamic observcances
# - `jdconverter`: converts dates between the Julian/Gregorian calendar and Julian date
#
# You can find a description of the various parameters in the docs link above.

# %%
configuration = load_config()  # load config.yml

ECLIPSE_API_URL = configuration['usno_solar_eclipse']['url']
## NOTE: This API doesn't require a key

# %%
def get_local_eclipse_data(geocode):
    """Get data on the solar eclipse at a particular location."""
    query_params = {
        "date": "8/21/2017",
        "coords": geocode,
        "format": "json"
    }
    response = requests.get(
        ECLIPSE_API_URL,
        params=query_params
    )
    return response.json()

# %%
geocode = "46.67,1.48"
get_local_eclipse_data(geocode)
# Out:
# {'apiversion': '2.0.0',
#  'day': 21,
#  'deltaT': '69.4s',
#  'description': 'Sun in Partial Eclipse at this Location',
#  'duration': '0h 11m 08.6s',
#  'error': False,
#  'event': 'Solar Eclipse of 2017 Aug. 21',
#  'height': '0m',
#  'lat': '46.670000',
#  'local_data': [{'altitude': '1.0',
#    'azimuth': '286.3',
#    'day': '21',
#    'phenomenon': 'Eclipse Begins',
#    'position_angle': '229.3',
#    'time': '18:42:26.8',
#    'vertex_angle': '187.0'},
#   {'altitude': '----',
#    'azimuth': '288.3',
#    'day': '21',
#    'phenomenon': 'Sunset',
#    'time': '18:54'}],
#  'lon': '1.480000',
#  'magnitude': '0.158',
#  'month': 8,
#  'obscuration': '7.4%',
#  'tz': '0',
#  'year': 2017}

# %% [markdown]
# ## Google Maps APIs
#
# Google provides lots of useful public APIs, including their Maps APIs:
#
# https://developers.google.com/maps/web-services/
#
# We will use Google Map's geocoding API to get latitude and longitude coordinates (a geocode) for a given postcode.
#
# For contrast, we'll use the `geopy` Python client wrapper for getting a timezone ID after getting a geocode from a postcode.
#
# From their GitHub page: "geopy is a Python 2 and 3 client for several popular geocoding web services."
#
# https://github.com/geopy/geopy

# %%
configuration = load_config()

GEOCODING_API_URL = configuration['google_geocoding']['url']
GEOCODING_API_KEY = configuration['google_geocoding']['key']

# %%
import time


def geocode_postcode_data(postcode):
    """Use Google geocode API to get geocode from postcode."""
    print("get the geocode for postcode {}".format(postcode))
    if not postcode:
        return None
    time.sleep(1)  # avoid rate limiting if calling this function in a loop
    url = "{}/json?components=postal_code:{}&key={}".format(
        GEOCODING_API_URL,
        postcode,
        GEOCODING_API_KEY
    )
    r = requests.get(url)
    postcode_geocode = None
    if r.status_code == 200:
        results = r.json()['results']
        if len(results) > 0:
            location = results[0]['geometry']['location']
            postcode_geocode = "{},{}".format(location['lat'], location['lng'])
    return postcode_geocode

# %%
! pip install geopy

# %%
from geopy import geocoders


def get_timezone(geocode):
    """Use geopy client to get timezone from lat/lon."""
    # Localize the event times
    lat = float(geocode.split(',')[0])
    lon = float(geocode.split(',')[1])
    # Get timezone from lat/lon
    g = geocoders.GoogleV3()
    timezone = str(g.timezone((lat, lon)))
    return timezone

# %% [markdown]
# Now let's write a function to localize a datetime object to a particular timezone and format it as a more easily human-readable string.

# %%
import datetime as dt
import pytz


def localize_time(time_string, timezone_id):
    time_split = time_string.split(':')
    datetime = dt.datetime(2017, 8, 21, int(time_split[0]), int(time_split[1]))
    utc_datetime = datetime.replace(tzinfo=pytz.utc)
    time_format = '%-I:%M %p %Z'  # e.g., '1:44 PM EST'

    # Convert timezone_id to pytz timezone object
    timezone = pytz.timezone(timezone_id)

    # Localize timezone-aware datetime object
    localized_datetime = utc_datetime.astimezone(timezone)

    return localized_datetime.strftime(time_format)

# %% [markdown]
# <div class="alert alert-info">
# **Exercise:** Use the above functions to get and print the begin time, the end time, and the maximum obscuration for the August 21, 2017 eclipse in your zip code and your time zone.
# </div>

# %%
## CODE HERE ##

# %%
MY_POSTCODE = 78731
geocode = geocode_postcode_data(MY_POSTCODE)
print(geocode)
print("")

dict_eclipse_data = get_local_eclipse_data(geocode)
# Out:
# get the geocode for postcode 78731
# 30.3542409,-97.7742702

# %%
dict_eclipse_data
# Out:
# {'apiversion': '2.0.0',
#  'day': 21,
#  'deltaT': '69.4s',
#  'description': 'Sun in Partial Eclipse at this Location',
#  'duration': '2h 58m 15.1s',
#  'error': False,
#  'event': 'Solar Eclipse of 2017 Aug. 21',
#  'height': '0m',
#  'lat': '30.354250',
#  'local_data': [{'altitude': '58.0',
#    'azimuth': '119.1',
#    'day': '21',
#    'phenomenon': 'Eclipse Begins',
#    'position_angle': '308.4',
#    'time': '16:41:01.2',
#    'vertex_angle': '358.8'},
#   {'altitude': '70.7',
#    'azimuth': '162.0',
#    'day': '21',
#    'phenomenon': 'Maximum Eclipse',
#    'time': '18:10:07.1'},
#   {'altitude': '66.1',
#    'azimuth': '222.7',
#    'day': '21',
#    'phenomenon': 'Eclipse Ends',
#    'position_angle': '97.8',
#    'time': '19:39:16.3',
#    'vertex_angle': '61.3'}],
#  'lon': '-97.774278',
#  'magnitude': '0.720',
#  'month': 8,
#  'obscuration': '65.4%',
#  'tz': '0',
#  'year': 2017}

# %%
for local in dict_eclipse_data['local_data']:
    print(local['phenomenon'], local['time'])
    
obscuration = dict_eclipse_data['obscuration']
print("Obscuration at Maximum Eclipse: {}".format(obscuration))
# Out:
# Eclipse Begins 16:41:01.2
# Maximum Eclipse 18:10:07.1
# Eclipse Ends 19:39:16.3
# Obscuration at Maximum Eclipse: 65.4%

# %%
timezone_id = get_timezone(geocode)
print(timezone_id)
# Out:
# America/Chicago

# %%
for local in dict_eclipse_data['local_data']:
    print(local['phenomenon'], localize_time(local['time'], timezone_id))
    
obscuration = dict_eclipse_data['obscuration']
print("Obscuration at Maximum Eclipse: {}".format(obscuration))
# Out:
# Eclipse Begins 11:41 AM CDT
# Maximum Eclipse 1:10 PM CDT
# Eclipse Ends 2:39 PM CDT
# Obscuration at Maximum Eclipse: 65.4%

# %% [markdown]
# ***
# ## Planet Data API
#
# Sign up for an Planet account [here](https://www.planet.com/account/#/). Log in and copy/paste your API key to your `config.yml` file.
#
# Docs: https://www.planet.com/docs/reference/data-api/

# %%
# Load the needed configuration file variables
cfg = load_config()
PLANET_API_URL = cfg['planet']['url']
PLANET_API_KEY = cfg['planet']['key']

# %% [markdown]
# The following example is taken from here:
# - https://github.com/planetlabs/notebooks/blob/master/jupyter-notebooks/data-api-tutorials/search_and_download_quickstart.ipynb.

# %% [markdown]
# ### Define an Area of Interest

# %%
# Stockton, CA bounding box (created via geojson.io) 
geojson_geometry = {
  "type": "Polygon",
  "coordinates": [
    [ 
      [-121.59290313720705, 37.93444993515032],
      [-121.27017974853516, 37.93444993515032],
      [-121.27017974853516, 38.065932950547484],
      [-121.59290313720705, 38.065932950547484],
      [-121.59290313720705, 37.93444993515032]
    ]
  ]
}

# %%
# # Austin, TX bounding box (created via geojson.io)
# geojson_geometry = {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [-97.84698486328125, 30.115433670851925],
#         [-97.63481140136719, 30.115433670851925],
#         [-97.63481140136719, 30.433281874927655],
#         [-97.84698486328125, 30.433281874927655],
#         [-97.84698486328125, 30.115433670851925]
#       ]
#     ]
# }

# %% [markdown]
# ### Create Filters

# %%
# get images that overlap with our AOI 
geometry_filter = {
  "type": "GeometryFilter",
  "field_name": "geometry",
  "config": geojson_geometry
}

# get images acquired within a date range
date_range_filter = {
  "type": "DateRangeFilter",
  "field_name": "acquired",
  "config": {
    "gte": "2016-08-31T00:00:00.000Z",
    "lte": "2016-09-01T00:00:00.000Z"
  }
}

# only get images which have <50% cloud coverage
cloud_cover_filter = {
  "type": "RangeFilter",
  "field_name": "cloud_cover",
  "config": {
    "lte": 0.5
  }
}

# combine our geo, date, cloud filters
combined_filter = {
  "type": "AndFilter",
  "config": [geometry_filter, date_range_filter, cloud_cover_filter]
}

# %% [markdown]
# ### Searching: Items and Assets
# You can learn more about item & asset types in Planet's Data API [here](https://www.planet.com/docs/reference/data-api/items-assets/).

# %%
import os
import json
import requests
from requests.auth import HTTPBasicAuth


item_type = "PSScene3Band"

# API request object
search_request = {
  "interval": "day",
  "item_types": [item_type], 
  "filter": combined_filter
}

# fire off the POST request
search_result = \
  requests.post(
    'https://api.planet.com/data/v1/quick-search',
    auth=HTTPBasicAuth(PLANET_API_KEY, ''),
    json=search_request)

print(json.dumps(search_result.json(), indent=1))
# Out:
# {
#  "_links": {
#   "_first": "https://api.planet.com/data/v1/searches/e10c42b5b9fa437cb00877322a1eb1f9/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/e10c42b5b9fa437cb00877322a1eb1f9/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6ICIyMDE2LTA5LTE1VDAxOjM3OjMzLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMTYwODMxXzE0Mzg0NV8wYzc5IiwgInNvcnRfZGVzYyI6IHRydWV9",
#   "_self": "https://api.planet.com/data/v1/searches/e10c42b5b9fa437cb00877322a1eb1f9/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D"
#  },
#  "features": [
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212703_0c43",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212703_0c43/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212703_0c43/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.40114083576219,
#        38.20593563301647
#       ],
#       [
#        -121.45977891677752,
#        38.24125495112041
#       ],
#       [
#        -121.60235758975814,
#        38.09255863673346
#       ],
#       [
#        -121.5434615097804,
#        38.057562707778104
#       ],
#       [
#        -121.40114083576219,
#        38.20593563301647
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_212703_0c43",
#    "properties": {
#     "acquired": "2016-08-31T21:27:03.039969Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 5810,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.1,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 622557,
#     "origin_y": 4233705.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:59:43Z",
#     "quality_category": "standard",
#     "rows": 6834,
#     "satellite_id": "0c43",
#     "strip_id": "232154",
#     "sun_azimuth": 216.8,
#     "sun_elevation": 55,
#     "updated": "2017-05-06T05:26:46Z",
#     "usable_data": 0,
#     "view_angle": 1.7
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212705_0c43",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212705_0c43/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212705_0c43/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.25363338170743,
#        38.1029936647547
#       ],
#       [
#        -121.3121325812552,
#        38.13837275872044
#       ],
#       [
#        -121.45473512061143,
#        37.98979329661326
#       ],
#       [
#        -121.39598663880153,
#        37.954756953931394
#       ],
#       [
#        -121.25363338170743,
#        38.1029936647547
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_212705_0c43",
#    "properties": {
#     "acquired": "2016-08-31T21:27:05.553514Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 5809,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.134838826577631,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 635691,
#     "origin_y": 4222515.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:59:42Z",
#     "quality_category": "standard",
#     "rows": 6836,
#     "satellite_id": "0c43",
#     "strip_id": "232154",
#     "sun_azimuth": 217.1,
#     "sun_elevation": 55,
#     "updated": "2017-05-04T16:14:03Z",
#     "usable_data": 0,
#     "view_angle": 1.8
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212706_0c43",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212706_0c43/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212706_0c43/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.20320458273174,
#        38.06820741563591
#       ],
#       [
#        -121.26163628343997,
#        38.10361543709027
#       ],
#       [
#        -121.40427102811434,
#        37.95507419389863
#       ],
#       [
#        -121.34554155742413,
#        37.92004450282888
#       ],
#       [
#        -121.20320458273174,
#        38.06820741563591
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_212706_0c43",
#    "properties": {
#     "acquired": "2016-08-31T21:27:06.38977Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 5809,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.1,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 640188,
#     "origin_y": 4218741.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:59:30Z",
#     "quality_category": "standard",
#     "rows": 6836,
#     "satellite_id": "0c43",
#     "strip_id": "232154",
#     "sun_azimuth": 217.2,
#     "sun_elevation": 55,
#     "updated": "2017-05-06T05:46:37Z",
#     "usable_data": 0,
#     "view_angle": 1.8
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212707_0c43",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212707_0c43/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212707_0c43/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.15236708636576,
#        38.03345596923921
#       ],
#       [
#        -121.21073869328715,
#        38.068895827490174
#       ],
#       [
#        -121.35345355696495,
#        37.920476467811135
#       ],
#       [
#        -121.2948066388568,
#        37.88539091356631
#       ],
#       [
#        -121.15236708636576,
#        38.03345596923921
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_212707_0c43",
#    "properties": {
#     "acquired": "2016-08-31T21:27:07.223909Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 5810,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.1342984835465493,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 644721,
#     "origin_y": 4214973.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:59:29Z",
#     "quality_category": "standard",
#     "rows": 6835,
#     "satellite_id": "0c43",
#     "strip_id": "232154",
#     "sun_azimuth": 217.4,
#     "sun_elevation": 55,
#     "updated": "2017-05-04T14:09:50Z",
#     "usable_data": 0,
#     "view_angle": 1.8
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212704_0c43",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212704_0c43/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212704_0c43/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.30304536347454,
#        38.13769624137661
#       ],
#       [
#        -121.3615650311499,
#        38.173068605819864
#       ],
#       [
#        -121.50421893005034,
#        38.02448384270298
#       ],
#       [
#        -121.44543437434727,
#        37.98945109378104
#       ],
#       [
#        -121.30304536347454,
#        38.13769624137661
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_212704_0c43",
#    "properties": {
#     "acquired": "2016-08-31T21:27:04.723994Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 5811,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.1,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 631284,
#     "origin_y": 4226289.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:59:25Z",
#     "quality_category": "standard",
#     "rows": 6835,
#     "satellite_id": "0c43",
#     "strip_id": "232154",
#     "sun_azimuth": 217,
#     "sun_elevation": 55,
#     "updated": "2017-05-06T05:32:22Z",
#     "usable_data": 0,
#     "view_angle": 1.8
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212703_1_0c43",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212703_1_0c43/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_212703_1_0c43/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.35209903416828,
#        38.17186914391526
#       ],
#       [
#        -121.410678985776,
#        38.20721795993714
#       ],
#       [
#        -121.55329173250338,
#        38.05856954823945
#       ],
#       [
#        -121.49445244364881,
#        38.023563585761046
#       ],
#       [
#        -121.35209903416828,
#        38.17186914391526
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_212703_1_0c43",
#    "properties": {
#     "acquired": "2016-08-31T21:27:03.883939Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 5810,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.134711958417252,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 626919,
#     "origin_y": 4230003.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:59:22Z",
#     "quality_category": "standard",
#     "rows": 6835,
#     "satellite_id": "0c43",
#     "strip_id": "232154",
#     "sun_azimuth": 216.9,
#     "sun_elevation": 55,
#     "updated": "2017-05-04T01:18:59Z",
#     "usable_data": 0,
#     "view_angle": 1.8
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180302_0e26",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180302_0e26/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180302_0e26/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.57048921271576,
#        38.065392343485954
#       ],
#       [
#        -121.59272090779002,
#        37.98944286184492
#       ],
#       [
#        -121.29367263094576,
#        37.935098068994286
#       ],
#       [
#        -121.2716275589425,
#        38.0113102816
#       ],
#       [
#        -121.57048921271576,
#        38.065392343485954
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_180302_0e26",
#    "properties": {
#     "acquired": "2016-08-31T18:03:02.59036Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 9385,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 4.1,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 623574,
#     "origin_y": 4214037.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:53:03Z",
#     "quality_category": "standard",
#     "rows": 4684,
#     "satellite_id": "0e26",
#     "strip_id": "231989",
#     "sun_azimuth": 128.6,
#     "sun_elevation": 49.3,
#     "updated": "2017-05-06T05:46:23Z",
#     "usable_data": 0,
#     "view_angle": 3.2
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180303_0e26",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180303_0e26/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180303_0e26/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.59030193050619,
#        37.99905957618311
#       ],
#       [
#        -121.61244782447446,
#        37.92310298380717
#       ],
#       [
#        -121.31366434662843,
#        37.86885590304515
#       ],
#       [
#        -121.29168558528465,
#        37.94508500534115
#       ],
#       [
#        -121.59030193050619,
#        37.99905957618311
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_180303_0e26",
#    "properties": {
#     "acquired": "2016-08-31T18:03:03.631837Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 9384,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 4.1,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 621951,
#     "origin_y": 4206651.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:53:02Z",
#     "quality_category": "standard",
#     "rows": 4683,
#     "satellite_id": "0e26",
#     "strip_id": "231989",
#     "sun_azimuth": 128.5,
#     "sun_elevation": 49.3,
#     "updated": "2017-05-06T05:11:23Z",
#     "usable_data": 0,
#     "view_angle": 3.1
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180301_0e26",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180301_0e26/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180301_0e26/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.54995317179335,
#        38.13195772248653
#       ],
#       [
#        -121.57227997368913,
#        38.056004580133084
#       ],
#       [
#        -121.27297386310153,
#        38.001527370835056
#       ],
#       [
#        -121.25085235535032,
#        38.07772837763579
#       ],
#       [
#        -121.54995317179335,
#        38.13195772248653
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_180301_0e26",
#    "properties": {
#     "acquired": "2016-08-31T18:03:01.540205Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 9386,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 4.0736934086111365,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 625257,
#     "origin_y": 4221450.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:52:58Z",
#     "quality_category": "standard",
#     "rows": 4687,
#     "satellite_id": "0e26",
#     "strip_id": "231989",
#     "sun_azimuth": 128.7,
#     "sun_elevation": 49.2,
#     "updated": "2017-05-06T02:18:51Z",
#     "usable_data": 0,
#     "view_angle": 3.2
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180235_0e0e",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180235_0e0e/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180235_0e0e/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.75811713295012,
#        38.10016228882786
#       ],
#       [
#        -121.78317511635869,
#        38.023073827924655
#       ],
#       [
#        -121.48700121922897,
#        37.9632738290554
#       ],
#       [
#        -121.46224865880401,
#        38.0404258887108
#       ],
#       [
#        -121.75811713295012,
#        38.10016228882786
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_180235_0e0e",
#    "properties": {
#     "acquired": "2016-08-31T18:02:35.82284Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 9380,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 4.1,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 606801,
#     "origin_y": 4217658.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:52:08Z",
#     "quality_category": "standard",
#     "rows": 4947,
#     "satellite_id": "0e0e",
#     "strip_id": "232396",
#     "sun_azimuth": 128.6,
#     "sun_elevation": 49.3,
#     "updated": "2017-05-06T05:04:21Z",
#     "usable_data": 0,
#     "view_angle": 0.8
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180236_0e0e",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180236_0e0e/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180236_0e0e/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.77830268980225,
#        38.033068371261
#       ],
#       [
#        -121.80328497890481,
#        37.95594856886622
#       ],
#       [
#        -121.50743620617904,
#        37.89615037260228
#       ],
#       [
#        -121.4827107983757,
#        37.973307297097975
#       ],
#       [
#        -121.77830268980225,
#        38.033068371261
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_180236_0e0e",
#    "properties": {
#     "acquired": "2016-08-31T18:02:36.869026Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 9378,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 4.055845784782086,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 605133,
#     "origin_y": 4210191.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:52:03Z",
#     "quality_category": "standard",
#     "rows": 4950,
#     "satellite_id": "0e0e",
#     "strip_id": "232396",
#     "sun_azimuth": 128.5,
#     "sun_elevation": 49.3,
#     "updated": "2017-05-06T02:29:44Z",
#     "usable_data": 0,
#     "view_angle": 0.7
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180234_0e0e",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180234_0e0e/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_180234_0e0e/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.73748870207397,
#        38.1668691704963
#       ],
#       [
#        -121.76255429451685,
#        38.0897642974976
#       ],
#       [
#        -121.46612008099623,
#        38.029962977779356
#       ],
#       [
#        -121.44133864603887,
#        38.10711876670736
#       ],
#       [
#        -121.73748870207397,
#        38.1668691704963
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_180234_0e0e",
#    "properties": {
#     "acquired": "2016-08-31T18:02:34.776554Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 9381,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 4.1,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 608511,
#     "origin_y": 4225083,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:52:03Z",
#     "quality_category": "standard",
#     "rows": 4945,
#     "satellite_id": "0e0e",
#     "strip_id": "232396",
#     "sun_azimuth": 128.7,
#     "sun_elevation": 49.2,
#     "updated": "2017-10-02T07:26:07Z",
#     "usable_data": 0,
#     "view_angle": 0.8
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143848_0c79",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143848_0c79/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143848_0c79/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.50591807095944,
#        38.24628061657084
#       ],
#       [
#        -121.56266072958888,
#        38.21112352052
#       ],
#       [
#        -121.4162365516695,
#        38.06456609980321
#       ],
#       [
#        -121.3597589019274,
#        38.099945047723715
#       ],
#       [
#        -121.50591807095944,
#        38.24628061657084
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_143848_0c79",
#    "properties": {
#     "acquired": "2016-08-31T14:38:48.006174Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 5995,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.1379588957189255,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 625833,
#     "origin_y": 4234197.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:37:41Z",
#     "quality_category": "standard",
#     "rows": 6679,
#     "satellite_id": "0c79",
#     "strip_id": "232281",
#     "sun_azimuth": 88.5,
#     "sun_elevation": 11.7,
#     "updated": "2017-05-04T16:13:04Z",
#     "usable_data": 0,
#     "view_angle": 2.9
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143847_0c79",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143847_0c79/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143847_0c79/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.55654728597658,
#        38.21330488778123
#       ],
#       [
#        -121.61324973102154,
#        38.17813652158631
#       ],
#       [
#        -121.46679977667304,
#        38.03163242569482
#       ],
#       [
#        -121.41038132149336,
#        38.06702918552587
#       ],
#       [
#        -121.55654728597658,
#        38.21330488778123
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_143847_0c79",
#    "properties": {
#     "acquired": "2016-08-31T14:38:47.168105Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 5995,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.1,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 621459,
#     "origin_y": 4230468.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:37:41Z",
#     "quality_category": "standard",
#     "rows": 6678,
#     "satellite_id": "0c79",
#     "strip_id": "232281",
#     "sun_azimuth": 88.5,
#     "sun_elevation": 11.7,
#     "updated": "2017-05-06T05:32:08Z",
#     "usable_data": 0,
#     "view_angle": 2.9
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143846_0c79",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143846_0c79/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143846_0c79/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.60663799713524,
#        38.1800756054562
#       ],
#       [
#        -121.6632455031279,
#        38.14485099973482
#       ],
#       [
#        -121.5165922692313,
#        37.99849103117107
#       ],
#       [
#        -121.46026269944547,
#        38.03393755010993
#       ],
#       [
#        -121.60663799713524,
#        38.1800756054562
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_143846_0c79",
#    "properties": {
#     "acquired": "2016-08-31T14:38:46.333255Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 5998,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.138209752633643,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 617133,
#     "origin_y": 4226715.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:37:38Z",
#     "quality_category": "standard",
#     "rows": 6677,
#     "satellite_id": "0c79",
#     "strip_id": "232281",
#     "sun_azimuth": 88.4,
#     "sun_elevation": 11.7,
#     "updated": "2017-05-04T02:38:27Z",
#     "usable_data": 0,
#     "view_angle": 2.9
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143843_1_0c79",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143843_1_0c79/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143843_1_0c79/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.70708461561117,
#        38.112427726582695
#       ],
#       [
#        -121.76359768087968,
#        38.077138347707
#       ],
#       [
#        -121.61682190139382,
#        37.93091698247259
#       ],
#       [
#        -121.56057999176052,
#        37.966419031843
#       ],
#       [
#        -121.70708461561117,
#        38.112427726582695
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_143843_1_0c79",
#    "properties": {
#     "acquired": "2016-08-31T14:38:43.947766Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 6000,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.1386941927124448,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 608439,
#     "origin_y": 4219080.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:37:38Z",
#     "quality_category": "standard",
#     "rows": 6676,
#     "satellite_id": "0c79",
#     "strip_id": "232281",
#     "sun_azimuth": 88.3,
#     "sun_elevation": 11.5,
#     "updated": "2017-05-04T01:47:55Z",
#     "usable_data": 0,
#     "view_angle": 2.1
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143845_0c79",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143845_0c79/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160831_143845_0c79/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.65632403908735,
#        38.146302634773896
#       ],
#       [
#        -121.71289901877186,
#        38.11108453055987
#       ],
#       [
#        -121.56620607239063,
#        37.96478447430404
#       ],
#       [
#        -121.50996196012768,
#        38.00025899068789
#       ],
#       [
#        -121.65632403908735,
#        38.146302634773896
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20160831_143845_0c79",
#    "properties": {
#     "acquired": "2016-08-31T14:38:45.499088Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 5997,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.137368561825563,
#     "instrument": "PS2",
#     "item_type": "PSScene3Band",
#     "origin_x": 612834,
#     "origin_y": 4222902.0,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2016-09-15T01:37:33Z",
#     "quality_category": "standard",
#     "rows": 6675,
#     "satellite_id": "0c79",
#     "strip_id": "232281",
#     "sun_azimuth": 88.4,
#     "sun_elevation": 11.6,
#     "updated": "2017-05-06T01:03:18Z",
#     "usable_data": 0,
#     "view_angle": 2.8
#    },
#    "type": "Feature"
#   }
#  ],
#  "type": "FeatureCollection"
# }

# %%
# extract image IDs only
image_ids = [feature['id'] for feature in search_result.json()['features']]
print(image_ids)
# Out:
# ['20160831_212703_0c43', '20160831_212705_0c43', '20160831_212706_0c43', '20160831_212707_0c43', '20160831_212704_0c43', '20160831_212703_1_0c43', '20160831_180302_0e26', '20160831_180303_0e26', '20160831_180301_0e26', '20160831_180235_0e0e', '20160831_180236_0e0e', '20160831_180234_0e0e', '20160831_143848_0c79', '20160831_143847_0c79', '20160831_143846_0c79', '20160831_143843_1_0c79', '20160831_143845_0c79']

# %%
# For demo purposes, just grab the first image ID
id0 = image_ids[0]
id0_url = 'https://api.planet.com/data/v1/item-types/{}/items/{}/assets'.format(item_type, id0)

# Returns JSON metadata for assets in this ID. Learn more: planet.com/docs/reference/data-api/items-assets/#asset
result = \
  requests.get(
    id0_url,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# List of asset types available for this particular satellite image
print(result.json().keys())
# Out:
# dict_keys(['analytic', 'analytic_xml', 'udm', 'visual', 'visual_xml'])

# %% [markdown]
# ### Activation and Downloading

# %%
# This is "inactive" if the "visual" asset has not yet been activated; otherwise 'active'
print(result.json()['visual']['status'])
# Out:
# active

# %%
# Parse out useful links
links = result.json()[u"visual"]["_links"]
self_link = links["_self"]
activation_link = links["activate"]

# Request activation of the 'visual' asset:
activate_result = \
  requests.get(
    activation_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# %%
activation_status_result = \
  requests.get(
    self_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )
    
print(activation_status_result.json()["status"])
# Out:
# active

# %%
# Image can be downloaded by making a GET with your Planet API key, from here:
download_link = activation_status_result.json()["location"]
print(download_link)
# Out:
# https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..W7iTIsStVJ3OXhYI4Gk8Hq0OZR-X-J1DxAs13jkTITQO9EQM9Per0ODtbx-39Too-fnW2Smtwhd1YVhVZjGSPQ

# %% [markdown]
# ***
# ## Twitter APIs
# https://developer.twitter.com/en/docs
#
# In this case there is a well-written Python client wrapper called `twython` that can be used in lieue of the lower level `requests` library (or the lower-level `http.client` library).
#
# This paragraph from "Data Science from Scratch" is on point:
#
# > "Typically we won’t be working with APIs at this low “make the requests and parse the
# responses ourselves” level. One of the benefits of using Python is that someone has
# already built a library for pretty much any API you’re interested in accessing. When
# they’re done well, these libraries can save you a lot of the trouble of figuring out the
# hairier details of API access. (When they’re not done well, or when it turns out they’re
# based on defunct versions of the corresponding APIs, they can cause you enormous
# headaches.)
#
# > Nonetheless, you’ll occasionally have to roll your own API-access library (or, more
# likely, debug why someone else’s isn’t working), so it’s good to know some of the
# details."

# %% [markdown]
# ### Get  Your Twitter Credentials
# Sign in to your Twitter account and go to https://apps.twitter.com/. We'll go over this part together.
#
# The following example is taken from here:
# - https://github.com/joelgrus/data-science-from-scratch/blob/master/code/getting_data.py

# %%
configuration = load_config()

# these should be in your 
CONSUMER_KEY = configuration['twitter']['consumer_key']
CONSUMER_SECRET = configuration['twitter']['consumer_secret']
ACCESS_TOKEN = configuration['twitter']['access_token']
ACCESS_TOKEN_SECRET = configuration['twitter']['access_token_secret']

# %% [markdown]
# ### Twitter Search API

# %%
from twython import Twython


def call_twitter_search_api():

    twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET)

    # search for tweets containing the phrase "data science"
    for status in twitter.search(q='"data science"')["statuses"]:
        user = status["user"]["screen_name"].encode('utf-8')
        text = status["text"].encode('utf-8')
        print(user, ":", text)
        print("")

# %%
# search for tweets containing the phrase "data science"
call_twitter_search_api()
# Out:
# b'alevergara78' : b'RT @tpalczew: Ranking Popular Deep Learning Libraries for Data Science https://t.co/mfeL0gSYg5 #DataScience #MachineLearning'
#
# b'data_science_cl' : b'RT @Natiuu_: "tamoslisteilor" exclam\xc3\xb3 la princesa. Basta con que los mismos vuelvan a ir a votar para que la oposici\xc3\xb3n no sea electa.\n\nPero\xe2\x80\xa6'
#
# b'NVSData' : b'RT @tpalczew: Ranking Popular Deep Learning Libraries for Data Science https://t.co/mfeL0gSYg5 #DataScience #MachineLearning'
#
# b'rominejl' : b'RT @Taylor_Soper: Working Geek: Redfin chief economist @NelaRichardson believes data science can help with affordable housing challenges.\nI\xe2\x80\xa6'
#
# b'websecurite' : b'RT @CyberDomain: This book provides a scientific modeling approach for conducting me https://t.co/aHyhPzTqyI\xe2\x80\xa6 https://t.co/blC4ejXWfS'
#
# b'SidSom1' : b'Automated Valuation Modeling (AVM) \xe2\x80\x93 A Fully Explained and Illustrated Data Science Guide https://t.co/SzEdjvXAAQ'
#
# b'Subhash_Kumar' : b'RT @Ronald_vanLoon: Best Online Masters in Data Science and Analytics \xe2\x80\x93 a comprehensive, unbiased survey | #DataScience #Analytics #RT http\xe2\x80\xa6'
#
# b'jogender_emc2' : b'RT @STPIVizag: Inaugural address by Shri. M.P.Dubey, JD &amp; OIC, @STPIVizag @AICTE_INDIA International Conference on "Smart Technologies in D\xe2\x80\xa6'
#
# b'CindyOKeeffe' : b'RT @DigitalGlobe: Meet #GBDX Notebooks: simplifying Earth imagery to advance data science w/ Amazon #SageMaker. #reInvent https://t.co/miHu\xe2\x80\xa6'
#
# b'TamaraRPearce' : b'RT @drob: Wow- NLP analysis discovers more than a million fake anti-net-neutrality comments. Brilliant data science detective work by @this\xe2\x80\xa6'
#
# b'BillPetti' : b'RT @gelliottmorris: News: I\xe2\x80\x99m teaming up with @DataCamp to produce a course about learning data science (R) through politics/polling/electi\xe2\x80\xa6'
#
# b'SidSom1' : b'Automated Valuation Modeling (AVM) - A Step-by-Step Data Science Guide (5 Illustrated Models) https://t.co/WwzlmL7W29'
#
# b'MrAhmednurAli' : b"RT @PeterKimData: Over 30 data scientists, programmers, coders, engineers have RSVPd to @dataforgoodyvr's first datathon in support of Vanc\xe2\x80\xa6"
#
# b'tpalczew' : b'Ranking Popular Deep Learning Libraries for Data Science https://t.co/mfeL0gSYg5 #DataScience #MachineLearning'
#
# b'jauhari_mayank' : b'https://t.co/xVrpE7bwk4'

# %% [markdown]
# ### Twitter Streaming API

# %%
from twython import TwythonStreamer


# appending data to a global variable is pretty poor form
# but it makes the example much simpler
tweets = [] 

class MyStreamer(TwythonStreamer):
    """our own subclass of TwythonStreamer that specifies
    how to interact with the stream"""

    def on_success(self, data):
        """what do we do when twitter sends us data?
        here data will be a Python object representing a tweet"""

        # only want to collect English-language tweets
        if data['lang'] == 'en':
            tweets.append(data)

        # stop when we've collected enough
        if len(tweets) >= 100:
            self.disconnect()

    def on_error(self, status_code, data):
        print(status_code, data)
        self.disconnect()

def call_twitter_streaming_api():
    stream = MyStreamer(CONSUMER_KEY, CONSUMER_SECRET, 
                        ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

    # starts consuming public statuses that contain the keyword 'data'
    stream.statuses.filter(track='data')
    
    ## if instead we wanted to start consuming a sample of *all* public statuses
    # stream.statuses.sample()

# %%
call_twitter_streaming_api()

# %%
len(tweets)
# Out:
# 100

# %%
tweets[4]['text']
# Out:
# 'RT @Cisco_Jasper: Why your business needs @Cisco_Jasper &amp; @Cisco Kinetic #IoT platforms: https://t.co/1rZ3TBpjJT #IoT… '

# %% [markdown]
# <div class="alert alert-info">
# **Exercise:** Find the most common hashtags in `tweets`.
# </div>

# %%
## CODE HERE ##

# %%
top_hashtags = Counter(
    hashtag['text'].lower()
    for tweet in tweets
    for hashtag in tweet["entities"]["hashtags"]
)
print(top_hashtags.most_common(5))
# Out:
# [('machinelearning', 6), ('bigdata', 5), ('iot', 4), ('datascience', 3), ('data', 3)]

# %% [markdown]
# ## Thanks for Coming!
#
# - agarwal.meghann@gmail.com
# - https://www.linkedin.com/in/meghann-agarwal/
